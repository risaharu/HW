# %%
import pandas as pd

# Load the datasets
red_wine_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv'
white_wine_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-white.csv'

# Load datasets into DataFrames
red_wine_df = pd.read_csv(red_wine_url, sep=';')
white_wine_df = pd.read_csv(white_wine_url, sep=';')

# Get missing data counts for each dataset
red_wine_missing = red_wine_df.isnull().sum()
white_wine_missing = white_wine_df.isnull().sum()

print("Red Wine Dataset Missing Data Counts:")
print(red_wine_missing)

print("\nWhite Wine Dataset Missing Data Counts:")
print(white_wine_missing)
# Out:
# Red Wine Dataset Missing Data Counts:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64
#
# White Wine Dataset Missing Data Counts:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# ### Summary of Interaction
#
# 1. **Dataset Requests**:
#    - You asked for datasets that are amusing, funny, or otherwise interesting, which also have missing values and are available online through a CSV file.
#    - I provided several datasets, including:
#      - Drunk Driving Dataset
#      - Titanic Dataset
#      - House Prices Dataset
#      - World Happiness Dataset
#      - NBA Player Stats Dataset
#      - US Baby Names Dataset
#      - Star Wars Survey Dataset
#
# 2. **Specific Request**:
#    - You requested a dataset related to wine quality and asked for code to load the data into a Jupyter notebook using pandas and to get the counts of missing data.
#
# 3. **Final Code Provided**:
#    - I provided the following code to load the Wine Quality datasets and count missing values:
#
#    ```python
#    import pandas as pd
#
#    # Load the datasets
#    red_wine_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv'
#    white_wine_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-white.csv'
#
#    # Load datasets into DataFrames
#    red_wine_df = pd.read_csv(red_wine_url, sep=';')
#    white_wine_df = pd.read_csv(white_wine_url, sep=';')
#
#    # Get missing data counts for each dataset
#    red_wine_missing = red_wine_df.isnull().sum()
#    white_wine_missing = white_wine_df.isnull().sum()
#
#    print("Red Wine Dataset Missing Data Counts:")
#    print(red_wine_missing)
#
#    print("\nWhite Wine Dataset Missing Data Counts:")
#    print(white_wine_missing)
#    ```
#
#    **Explanation**:
#    - The code loads the red and white wine quality datasets from the UCI Machine Learning Repository.
#    - It uses `pd.read_csv` to read the CSV files, specifying `;` as the separator.
#    - It counts and prints the number of missing values for each column in both datasets.
